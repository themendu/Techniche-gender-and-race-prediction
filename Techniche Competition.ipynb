# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
test_set=pd.read_csv('test.csv')
train_set=pd.read_csv('train.csv')
sample_submission=pd.read_csv('sampleSubmission.csv')

# %%
train_set.head(10)
# Out:
#   last_name    first_name gender      race
# 0     james   harold d ii      m     black
# 1     cason    bruce g jr      m     black
# 2      lane     rommie l       m     black
# 3    lathan    melvin  jr      m     black
# 4     colon      javier        m  hispanic
# 5  copeland      james l       m     black
# 6     singh          miha      m    indian
# 7     kumar         vinit      m    indian
# 8       NaN        rajani      f    indian
# 9      hall     robert a       m     black

# %%
train_set.shape
# Out:
# (85272, 4)

# %%
train_set.dtypes
# Out:
# last_name     object
# first_name    object
# gender        object
# race          object
# dtype: object

# %%
train_set['gender'].unique()
# Out:
# array(['m', 'f'], dtype=object)

# %%
train_set['race'].unique()
# Out:
# array(['black', 'hispanic', 'indian', 'white'], dtype=object)

# %%
train_set.isnull().sum()
train_set.fillna('',inplace=True)
test_set.fillna('',inplace=True)

# %%
from sklearn.model_selection import train_test_split
X=np.asanyarray(train_set[['first_name','last_name']])

Y=np.asanyarray(train_set[['gender']])
#X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.33)

# %%
train_names=np.concatenate((np.array(train_set['first_name'].unique()),np.array(train_set['last_name'].unique())),axis=0)
test_names=np.concatenate((np.array(test_set['first_name'].unique()),np.array(test_set['last_name'].unique())),axis=0)

#out of a total of 57081 names 52711 were unique

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
train_vectors = vectorizer.fit_transform(data1)

test2_vectors=vectorizer.transform(data3)

# %%
from sklearn.naive_bayes import MultinomialNB
x_hat1234=MultinomialNB().fit(train_vectors,y_train_new)

y_hat_gender=x_hat1234.predict(test2_vectors)

# %%
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(train_vectors, y_train_new)

#Predict the response for test dataset
#y_pred = clf.predict(test_vectors)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
y_final_prediction_for_race=clf.predict(test2_vectors)

# %%
from  sklearn.metrics  import accuracy_score
print(accuracy_score(y_test,y_pred,normalize=True))
# Out:
# 0.9466595593461266

# %%
from  sklearn.metrics  import accuracy_score
predicted = clf.predict(test_vectors)
print(accuracy_score(y_test,predicted))


from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))

# %%
data1 = [" ".join(x) for x in X]
data1=np.array(data1)

#data2 = [" ".join(x) for x in X_test]
#data2=np.array(data2)

y_train_new=np.reshape(Y,(85272,))

# %%
X12=np.asanyarray(test_set[['last_name','first_name']])
data3= [" ".join(x) for x in X12 ]
data3=np.array(data3)

# %%
answer_df=pd.read_csv('answer_to.csv')
answer_df1=answer_df.copy()

answer_df1['race']=y_hat_race

# %%
answer_df1['gender']=y_hat_gender
answer_df1['race']=y_hat_race

# %%
# import the modules we'll need
from IPython.display import HTML
import pandas as pd
import numpy as np
import base64

# function that takes in a dataframe and creates a text link to  
# download it (will only work for files < 2MB or so)
def create_download_link(df, title = "Download CSV file", filename = "data.csv"):  
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

# create a random sample dataframe
df = pd.DataFrame(np.random.randn(50, 4), columns=list('ABCD'))

# create a link to download the dataframe
create_download_link(answer_df1)

# ↓ ↓ ↓  Yay, download link! ↓ ↓ ↓
# Out:
# <a download="data.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>

# %%
answer_df1['race'][5040]
# Out:
# 'black'

# %%
answer_df1['race'][5040]
# Out:
# 'white'

# %%
test_set.shape
# Out:
# (12186, 3)

# %%
y_final_prediction_for_gender.shape
# Out:
# (12186,)
